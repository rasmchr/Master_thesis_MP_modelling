# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from param_estim_it4_alteration import run_mcmc

# %%
import numpy as np
import matplotlib.pyplot as plt

#alpha = 9.156
#Da    = 1.13
#lambda_ = np.sqrt(alpha / Da)
#kappa   = 0.023
#u1      = 82665.16
#u2      = 0.0059

alpha = np.mean([1.74, 1.30, 0.87]) 
Da = 1
lambda_ = np.sqrt(alpha/Da)
kappa = 1.42*10**(-2)
u1= 3.65*10**5
u2= 0.01
C = 5.0

t       = np.linspace(0, 70, 100_000)
z1      = np.linspace(0,  50, 50_000)
z2_phys = np.linspace(50, 150, 100_000)


# ── B1 ──────────────────────────────────────────────────────────────────────
def B_func51(z, t_val, u1, alpha, lambda_, kappa, C):
    a  = kappa - lambda_ * u1
    b_ss  = (alpha / a) * C * np.exp(-lambda_ * z) * (1 - np.exp(-a * z / u1))
    b_tr  = (alpha / a) * np.exp(-lambda_ * z) * (1 - np.exp(-a * t_val))
    return np.where(z <= u1 * t_val, b_ss, b_tr)


# ── B1 evaluated exactly at z = 50 ──────────────────────────────────────────
def B1_at_50(t_array, u1, alpha, lambda_, kappa, C):
    """Simply evaluate B_func51 at z=50 for each t — no clamp."""
    return B_func51(50.0, t_array, u1, alpha, lambda_, kappa, C)


# ── Interface ODE — convolution integral ─────────────────────────────────────
def interface_M(t_array, u1, u2, alpha, lambda_, kappa, C):
    """
    M(t) = ∫₀ᵗ  u1 · B1(50, τ) · exp(−u2·(t−τ))  dτ

    Computed incrementally so we only do O(N) work instead of O(N²).
    Update rule (trapezoidal, step by step):
        M(t_{n+1}) = M(t_n)·exp(−u2·Δt)
                   + Δt·u1·½·[B1(50,t_n)·exp(−u2·Δt) + B1(50,t_{n+1})]
    This is the exact integral assuming B1 is linear between steps.
    """
    t_array = np.asarray(t_array)
    M       = np.zeros_like(t_array)
    B1_vals = B1_at_50(t_array, u1, alpha, lambda_, kappa, C)
    print("These are the B1 vals: ", B1_vals, "This is the length: ", len(B1_vals))

    for i in range(1, len(t_array)):
        dt_i   = t_array[i] - t_array[i - 1]
        decay  = np.exp(-u2 * dt_i)
        # trapezoidal on the integrand f(τ) = u1·B1(50,τ) between t_{i-1} and t_i
        f_prev = u1 * B1_vals[i - 1]
        f_curr = u1 * B1_vals[i]
        M[i]   = M[i - 1] * decay + dt_i * 0.5 * (f_prev * decay + f_curr)

    return M


# ── B2 ──────────────────────────────────────────────────────────────────────
def B_func52(z2_phys, t_val, u2, alpha, lambda_, t_array, kappa, M_vals, C):
    a2 = kappa - lambda_ * u2
    z2 = z2_phys - 50.0        # shifted coordinate (0 at interface)

    # Characteristic travel time from interface to z
    tau_travel = z2 / u2

    # Retarded time (clipped to [0, t_val] and to array bounds)
    tau = np.clip(t_val - tau_travel, 0.0, t_array[-1])

    # M interpolated at the retarded time
    M_tau = np.interp(tau, t_array, M_vals)

    # Branch 1: characteristic has arrived (z2 ≤ u2·t_val)
    b1 = ( (alpha / a2) * C * np.exp(-lambda_ * z2_phys)
           + (M_tau - (alpha / a2) * C * np.exp(-lambda_ * 50.0))
             * np.exp(-kappa * tau_travel) )

    # Branch 2: characteristic has not yet arrived
    b2 = (alpha / a2) * C * np.exp(-lambda_ * z2_phys) * (1.0 - np.exp(-a2 * t_val))

    return np.where(z2 <= u2 * t_val, b1, b2)


# ── Compute M once ───────────────────────────────────────────────────────────
M_vals = interface_M(t, u1, u2, alpha, lambda_, kappa, C)

# ── Plot ─────────────────────────────────────────────────────────────────────
z_full = np.concatenate([z1, z2_phys])
A_full = np.exp(-lambda_ * z_full)

indices   = np.linspace(0, len(t) - 1, 10, dtype=int)
t_sampled = t[indices]

plt.figure(figsize=(12, 5))
for ti in t_sampled:
    B1 = B_func51(z1, ti, u1, alpha, lambda_, kappa, C)
    B2 = B_func52(z2_phys, ti, u2, alpha, lambda_, t, kappa, M_vals, C)
    B  = np.concatenate([B1, B2])
    print(max(B))
    plt.plot(B, z_full, label=f"t={ti:.1f}")

plt.plot(A_full, z_full, 'k-.', label="A (source)")
plt.axhline(50, linestyle='--', color='grey', label="Interface z=50")
plt.gca().invert_yaxis()
plt.xlabel("Concentration")
plt.ylabel("Depth (m)")
plt.grid(True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Træning 3\AppData\Local\Temp\ipykernel_1616\3323125248.py:28: RuntimeWarning: overflow encountered in exp
#   b_tr  = (alpha / a) * np.exp(-lambda_ * z) * (1 - np.exp(-a * t_val))
# These are the B1 vals:  [-0.00000000e+00  1.87665875e-05  1.87665875e-05 ...  1.87665875e-05
#   1.87665875e-05  1.87665875e-05] This is the length:  100000
# -0.0
# 51.254870489723494
# 98.67655692261786
# 142.54967841910525
# 183.13977410389967
# 220.69251280822465
# 255.43517996393794
# 287.57805323365835
# 317.31567520128425
# 344.8280308284871

# %%
print("Alpha", alpha, "Da", Da, "kappa", kappa, "U1", u1, "U2", u2, "C", C)
# Out:
# Alpha 1.3033333333333335 Da 1 kappa 0.014199999999999999 U1 365000.0 U2 0.01 C 6.0

# %%
# plot
from it4_anal_solver import B_funky
C = 5
zeta = np.linspace(0, 150, 1000)
for i in range(len(t_sampled)):
    ti = t_sampled[i]
    t = np.linspace(0, ti, 1000)  # NEW time array up to current ti
    full = B_funky(zeta, ti, u1, u2, alpha, Da, kappa, C, t)
    plt.plot(full, zeta, label=f"t={ti:.2f} years")
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    print(max(full))

    #print(f"Max error at t={ti:.2f} years: {np.max(error)}")
plt.ylabel("Depth (m)")
plt.xlabel("Concentration")
plt.axhline(y=50, linestyle='--',label="Seabed")
plt.gca().invert_yaxis()
plt.grid()

plt.tight_layout()
#plt.ylim(5,0)

plt.show()
# Out:
# 5.0
# 5.0
# 5.0
# 36.76310835357045
# 68.50925586690884
# 97.88098070219145
# 125.05587752623943
# 150.19825675710143
# 173.4601481612306
# 194.9821738428031
# c:\Users\Træning 3\OneDrive - Roskilde Universitet\12. semester\Speciale - General\Numerik\Scripts\MCMC\it4\it4_anal_solver.py:16: RuntimeWarning: overflow encountered in exp
#   b_tr  = (alpha / a) * np.exp(-lambda_ * z) * (1 - np.exp(-a * t_val))

# %%
L = 150.0

water_raw = [
    (2.5,   3.5667891682785307),
    (7.5,   2.6969926716060204),
    (12.5,  0.9080153525061379),
    (17.5,  0.5380893150797977),
    (27.5,  0.15000000000000002),
    (32.5,  0.17777777777777778),
    (42.5,  0.07500000000000001),
    (47.5,  0.1),
]
sediment_raw = [   # (bin_centre_cm, concentration)
    (0.0125,               634.7414656833154),
    (0.037500000000000006, 478.3568408220815),
    (0.0625,               970.1680149695655),
    (0.08750000000000001,  2343.5408338909124),
    (0.1125,               1420.2905042168202),
    (0.1375,               1237.2282190132125),
    (0.16250000000000003,  1026.581643277907),
    (0.1875,               299.62609220263096),
    (0.21250000000000002,  681.4776292062617),
    (0.2375,               458.20696863375105),
    (0.2625,               422.2530388157952),
    (0.3125,               640.1515738798312),
    (0.3875,               63.55031042845192),
    (0.41250000000000003,  187.55853823063677),
    (0.48750000000000004,  30.846954308574094),
    (0.5375000000000001,   30.516169700062356),
    (0.6125,               17.81769496827207),
]

water_z   = np.array([r[0]                for r in water_raw])
water_val = np.array([r[1]                for r in water_raw])
sed_z     = np.array([r[0] + 50.0 for r in sediment_raw])  # cm→m + offset
sed_val   = np.array([r[1]                for r in sediment_raw])

# Zero-padding: penalise mass past the last observed depth
pad_z   = np.arange(sed_z[-1] + 0.5, L + 0.5, 10)
pad_val = np.zeros(len(pad_z))

obs_z   = np.concatenate([water_z, sed_z, pad_z])
obs_val = np.concatenate([water_val, sed_val, pad_val])
# --- fixed solver inputs ---
t_final = 70.0
t_array = np.linspace(0, t_final, 2000)
z_grid  = np.linspace(0, 150, 2000)

# %%
plt.plot(obs_val, obs_z)

# %%
from param_estim_it4_alteration import run_mcmc
import numpy as np
C = 130
init_p = {
    'z_grid':  z_grid,
    't':       t_final,
    'Da':      Da,
    'u1':      u1,
    'u2':      u2,
    'C':      C,
    't_array': t_array,
    'alpha':   alpha,
    
}

# --- parameters to estimate ---
param_cfg = {
    #'alpha':   {'init': alpha,              'sigma': 0.1, 'lo': 1e-4,  'hi': 2000.0,  'proposal': 'uniform'},
    'C':      {'init': C,               'sigma': 0.5, 'lo': 1e-4,  'hi': 20_000,  'proposal': 'uniform'},
    'kappa':   {'init': kappa,         'sigma': 0.05, 'lo': 1e-6,  'hi': 20_000,   'proposal': 'uniform'},
    #'u1':       {'init': u1,   'sigma': 100, 'lo': 100,  'hi': 10**10,   'proposal': 'uniform'},
    #'u2':       {'init': u2,    'sigma': 0.01, 'lo': 1e-6,  'hi': 10.0,   'proposal': 'uniform'},
    'Da':      {'init': Da,            'sigma': 1, 'lo': 1e-6,  'hi': 10_000,   'proposal': 'uniform'}
}

other_weights = np.concatenate([
    water_val / np.max(water_val),
    sed_val   / np.max(sed_val),
    np.ones_like(pad_z)*0.5
])

other_weights = other_weights + 0.5
other_weights = other_weights/np.max(other_weights)


# --- run ---
final_state, saved_path = run_mcmc(
    obs_z          = obs_z,
    obs_val        = obs_val,
    init_p         = init_p,
    param_cfg      = param_cfg,
    num_iterations = 5_000_000,
    output_name    = f'Idealized_param_set_chain_Da_kappa_C_GoodWeights_5mio_its.h5',
    weights        = other_weights
)
# Out:
#   iter      0  cost=157.9159  accept rate=0.00
#   iter  10000  cost=54.3615  accept rate=0.27
#   iter  20000  cost=52.5418  accept rate=0.27
#   iter  30000  cost=50.9600  accept rate=0.26
#   iter  40000  cost=50.9797  accept rate=0.26
#   iter  50000  cost=51.9489  accept rate=0.26
#   iter  60000  cost=54.4550  accept rate=0.26
#   iter  70000  cost=50.1649  accept rate=0.26
#   iter  80000  cost=51.1644  accept rate=0.26
#   iter  90000  cost=51.7508  accept rate=0.26
#   iter 100000  cost=50.5615  accept rate=0.26
#   iter 110000  cost=51.0398  accept rate=0.26
#   iter 120000  cost=51.3119  accept rate=0.26
#   iter 130000  cost=51.2977  accept rate=0.26
#   iter 140000  cost=51.0496  accept rate=0.26
#   iter 150000  cost=50.5309  accept rate=0.26
#   iter 160000  cost=50.5279  accept rate=0.26
#   iter 170000  cost=50.8215  accept rate=0.26
#   iter 180000  cost=51.8720  accept rate=0.26
#   iter 190000  cost=51.1218  accept rate=0.26
#   iter 200000  cost=50.6232  accept rate=0.26
#   iter 210000  cost=51.1171  accept rate=0.26
#   iter 220000  cost=51.0584  accept rate=0.26
#   iter 230000  cost=51.4182  accept rate=0.26
#   iter 240000  cost=52.4238  accept rate=0.26
#   iter 250000  cost=50.7055  accept rate=0.26
#   iter 260000  cost=50.5718  accept rate=0.26
#   iter 270000  cost=50.9143  accept rate=0.26
#   iter 280000  cost=50.9536  accept rate=0.26
#   iter 290000  cost=53.1651  accept rate=0.26
#   iter 300000  cost=50.2985  accept rate=0.26
#   iter 310000  cost=52.8629  accept rate=0.26
#   iter 320000  cost=52.3730  accept rate=0.26
#   iter 330000  cost=50.7881  accept rate=0.26
#   iter 340000  cost=51.9234  accept rate=0.26
#   iter 350000  cost=50.6271  accept rate=0.26
#   iter 360000  cost=50.5248  accept rate=0.26
#   iter 370000  cost=53.9501  accept rate=0.26
#   iter 380000  cost=51.8376  accept rate=0.26
#   iter 390000  cost=51.6282  accept rate=0.26
#   iter 400000  cost=53.1546  accept rate=0.26
#   iter 410000  cost=53.0537  accept rate=0.26
#   iter 420000  cost=51.4061  accept rate=0.26
#   iter 430000  cost=51.3734  accept rate=0.26
#   iter 440000  cost=51.6560  accept rate=0.26
#   iter 450000  cost=50.8281  accept rate=0.26
#   iter 460000  cost=52.7210  accept rate=0.26
#   iter 470000  cost=50.5286  accept rate=0.26
#   iter 480000  cost=50.9856  accept rate=0.26
#   iter 490000  cost=50.3320  accept rate=0.26
#   iter 500000  cost=52.5343  accept rate=0.26
#   iter 510000  cost=50.5837  accept rate=0.26
#   iter 520000  cost=51.3525  accept rate=0.26
#   iter 530000  cost=53.1608  accept rate=0.26
#   iter 540000  cost=50.3860  accept rate=0.26
#   iter 550000  cost=50.9268  accept rate=0.26
#   iter 560000  cost=50.6570  accept rate=0.26
#   iter 570000  cost=50.9548  accept rate=0.26
#   iter 580000  cost=50.5898  accept rate=0.26
#   iter 590000  cost=53.1423  accept rate=0.26
#   iter 600000  cost=50.2084  accept rate=0.26
#   iter 610000  cost=51.0398  accept rate=0.26
#   iter 620000  cost=51.2124  accept rate=0.26
#   iter 630000  cost=51.2080  accept rate=0.26
#   iter 640000  cost=53.8186  accept rate=0.26
#   iter 650000  cost=50.7642  accept rate=0.26
#   iter 660000  cost=52.0780  accept rate=0.26
#   iter 670000  cost=51.5148  accept rate=0.26
#   iter 680000  cost=50.5131  accept rate=0.26
#   iter 690000  cost=51.0389  accept rate=0.26
#   iter 700000  cost=51.8174  accept rate=0.26
#   iter 710000  cost=51.6050  accept rate=0.26
#   iter 720000  cost=50.5889  accept rate=0.26
#   iter 730000  cost=51.0031  accept rate=0.26
#   iter 740000  cost=52.1289  accept rate=0.26
#   iter 750000  cost=52.7929  accept rate=0.26
#   iter 760000  cost=51.1701  accept rate=0.26
#   iter 770000  cost=51.8672  accept rate=0.26
#   iter 780000  cost=52.0399  accept rate=0.26
#   iter 790000  cost=50.9296  accept rate=0.26
#   iter 800000  cost=52.4911  accept rate=0.26
#   iter 810000  cost=51.4475  accept rate=0.26
#   iter 820000  cost=50.5148  accept rate=0.26
#   iter 830000  cost=50.8442  accept rate=0.26
#   iter 840000  cost=50.1692  accept rate=0.26
#   iter 850000  cost=51.2162  accept rate=0.26
#   iter 860000  cost=52.5217  accept rate=0.26
#   iter 870000  cost=50.5751  accept rate=0.26
#   iter 880000  cost=50.8558  accept rate=0.26
#   iter 890000  cost=50.2392  accept rate=0.26
#   iter 900000  cost=50.6954  accept rate=0.26
#   iter 910000  cost=51.0936  accept rate=0.26
#   iter 920000  cost=53.3397  accept rate=0.26
#   iter 930000  cost=50.5213  accept rate=0.26
#   iter 940000  cost=50.9039  accept rate=0.26
#   iter 950000  cost=51.2840  accept rate=0.26
#   iter 960000  cost=51.2384  accept rate=0.26
#   iter 970000  cost=51.2159  accept rate=0.26
#   iter 980000  cost=50.8043  accept rate=0.26
#   iter 990000  cost=50.1891  accept rate=0.26
#   iter 1000000  cost=52.0110  accept rate=0.26
#   iter 1010000  cost=50.1697  accept rate=0.26
#   iter 1020000  cost=52.1737  accept rate=0.26
#   iter 1030000  cost=50.5180  accept rate=0.26
#   iter 1040000  cost=51.0068  accept rate=0.26
#   iter 1050000  cost=50.7403  accept rate=0.26
#   iter 1060000  cost=52.7663  accept rate=0.26
#   iter 1070000  cost=51.4997  accept rate=0.26
#   iter 1080000  cost=50.1681  accept rate=0.26
#   iter 1090000  cost=53.1399  accept rate=0.26
#   iter 1100000  cost=50.8676  accept rate=0.26
#   iter 1110000  cost=51.5655  accept rate=0.26
#   iter 1120000  cost=51.4275  accept rate=0.26
#   iter 1130000  cost=50.3544  accept rate=0.26
#   iter 1140000  cost=52.2962  accept rate=0.26
#   iter 1150000  cost=50.9268  accept rate=0.26
#   iter 1160000  cost=50.3506  accept rate=0.26
#   iter 1170000  cost=50.3397  accept rate=0.26
#   iter 1180000  cost=50.9893  accept rate=0.26
#   iter 1190000  cost=52.9290  accept rate=0.26
#   iter 1200000  cost=50.4273  accept rate=0.26
#   iter 1210000  cost=51.5716  accept rate=0.26
#   iter 1220000  cost=52.0798  accept rate=0.26
#   iter 1230000  cost=52.6153  accept rate=0.26
#   iter 1240000  cost=56.1641  accept rate=0.26
#   iter 1250000  cost=53.8664  accept rate=0.26
#   iter 1260000  cost=53.3474  accept rate=0.26
#   iter 1270000  cost=52.8990  accept rate=0.26
#   iter 1280000  cost=53.3994  accept rate=0.26
#   iter 1290000  cost=55.8229  accept rate=0.26
#   iter 1300000  cost=52.0326  accept rate=0.26
#   iter 1310000  cost=52.1596  accept rate=0.26
#   iter 1320000  cost=50.9138  accept rate=0.26
#   iter 1330000  cost=51.3091  accept rate=0.26
#   iter 1340000  cost=52.1089  accept rate=0.26
#   iter 1350000  cost=51.6129  accept rate=0.26
#   iter 1360000  cost=52.4694  accept rate=0.26
#   iter 1370000  cost=50.5294  accept rate=0.26
#   iter 1380000  cost=50.6564  accept rate=0.26
#   iter 1390000  cost=55.6981  accept rate=0.26
#   iter 1400000  cost=50.2864  accept rate=0.26
#   iter 1410000  cost=50.2993  accept rate=0.26
#   iter 1420000  cost=50.5148  accept rate=0.26
#   iter 1430000  cost=52.0723  accept rate=0.26
#   iter 1440000  cost=51.3455  accept rate=0.26
#   iter 1450000  cost=51.4691  accept rate=0.26
#   iter 1460000  cost=50.9685  accept rate=0.26
#   iter 1470000  cost=52.5160  accept rate=0.26
#   iter 1480000  cost=50.8797  accept rate=0.26
#   iter 1490000  cost=50.8103  accept rate=0.26
#   iter 1500000  cost=50.3782  accept rate=0.26
#   iter 1510000  cost=53.5304  accept rate=0.26
#   iter 1520000  cost=52.2404  accept rate=0.26
#   iter 1530000  cost=50.4813  accept rate=0.26
#   iter 1540000  cost=50.6450  accept rate=0.26
#   iter 1550000  cost=52.0963  accept rate=0.26
#   iter 1560000  cost=52.2800  accept rate=0.26
#   iter 1570000  cost=51.9961  accept rate=0.26
#   iter 1580000  cost=54.2898  accept rate=0.26
#   iter 1590000  cost=52.8653  accept rate=0.26
#   iter 1600000  cost=52.3393  accept rate=0.26
#   iter 1610000  cost=50.8590  accept rate=0.26
#   iter 1620000  cost=51.2352  accept rate=0.26
#   iter 1630000  cost=51.6225  accept rate=0.26
#   iter 1640000  cost=51.0112  accept rate=0.26
#   iter 1650000  cost=50.3198  accept rate=0.26
#   iter 1660000  cost=52.2568  accept rate=0.26
#   iter 1670000  cost=50.2319  accept rate=0.26
#   iter 1680000  cost=50.9330  accept rate=0.26
#   iter 1690000  cost=51.4815  accept rate=0.26
#   iter 1700000  cost=51.4975  accept rate=0.26
#   iter 1710000  cost=51.3145  accept rate=0.26
#   iter 1720000  cost=51.3309  accept rate=0.26
#   iter 1730000  cost=50.6242  accept rate=0.26
#   iter 1740000  cost=50.6203  accept rate=0.26
#   iter 1750000  cost=51.2785  accept rate=0.26
#   iter 1760000  cost=50.6054  accept rate=0.26
#   iter 1770000  cost=50.6337  accept rate=0.26
#   iter 1780000  cost=50.7110  accept rate=0.26
#   iter 1790000  cost=51.5621  accept rate=0.26
#   iter 1800000  cost=51.3064  accept rate=0.26
#   iter 1810000  cost=50.5928  accept rate=0.26
#   iter 1820000  cost=51.6127  accept rate=0.26
#   iter 1830000  cost=51.7372  accept rate=0.26
#   iter 1840000  cost=52.4418  accept rate=0.26
#   iter 1850000  cost=51.3719  accept rate=0.26
#   iter 1860000  cost=50.6825  accept rate=0.26
#   iter 1870000  cost=50.7030  accept rate=0.26
#   iter 1880000  cost=51.4025  accept rate=0.26
#   iter 1890000  cost=50.6174  accept rate=0.26
#   iter 1900000  cost=50.4804  accept rate=0.26
#   iter 1910000  cost=50.4480  accept rate=0.26
#   iter 1920000  cost=52.1147  accept rate=0.26
#   iter 1930000  cost=51.7882  accept rate=0.26
#   iter 1940000  cost=50.6699  accept rate=0.26
#   iter 1950000  cost=52.3072  accept rate=0.26
#   iter 1960000  cost=50.5812  accept rate=0.26
#   iter 1970000  cost=51.6008  accept rate=0.26
#   iter 1980000  cost=51.8408  accept rate=0.26
#   iter 1990000  cost=50.4322  accept rate=0.26
#   iter 2000000  cost=50.9289  accept rate=0.26
#   iter 2010000  cost=50.3510  accept rate=0.26
#   iter 2020000  cost=51.2361  accept rate=0.26
#   iter 2030000  cost=50.5312  accept rate=0.26
#   iter 2040000  cost=50.2483  accept rate=0.26
#   iter 2050000  cost=50.8466  accept rate=0.26
#   iter 2060000  cost=50.8465  accept rate=0.26
#   iter 2070000  cost=51.8987  accept rate=0.26
#   iter 2080000  cost=52.2125  accept rate=0.26
#   iter 2090000  cost=50.8709  accept rate=0.26
#   iter 2100000  cost=51.4289  accept rate=0.26
#   iter 2110000  cost=51.5983  accept rate=0.26
#   iter 2120000  cost=50.8811  accept rate=0.26
#   iter 2130000  cost=50.4624  accept rate=0.26
#   iter 2140000  cost=53.7184  accept rate=0.26
#   iter 2150000  cost=53.7616  accept rate=0.26
#   iter 2160000  cost=54.2685  accept rate=0.26
#   iter 2170000  cost=51.6273  accept rate=0.26
#   iter 2180000  cost=51.1160  accept rate=0.26
#   iter 2190000  cost=50.6447  accept rate=0.26
#   iter 2200000  cost=50.4458  accept rate=0.26
#   iter 2210000  cost=50.6667  accept rate=0.26
#   iter 2220000  cost=51.5171  accept rate=0.26
#   iter 2230000  cost=57.8093  accept rate=0.26
#   iter 2240000  cost=51.9898  accept rate=0.26
#   iter 2250000  cost=52.5404  accept rate=0.26
#   iter 2260000  cost=52.9483  accept rate=0.26
#   iter 2270000  cost=53.4207  accept rate=0.26
#   iter 2280000  cost=51.9016  accept rate=0.26
#   iter 2290000  cost=53.7885  accept rate=0.26
#   iter 2300000  cost=53.3774  accept rate=0.26
#   iter 2310000  cost=50.7763  accept rate=0.26
#   iter 2320000  cost=57.5021  accept rate=0.26
#   iter 2330000  cost=50.6876  accept rate=0.26
#   iter 2340000  cost=50.1648  accept rate=0.26
#   iter 2350000  cost=50.5731  accept rate=0.26
#   iter 2360000  cost=51.1428  accept rate=0.26
#   iter 2370000  cost=51.0542  accept rate=0.26
#   iter 2380000  cost=50.6705  accept rate=0.26
#   iter 2390000  cost=52.3472  accept rate=0.26
#   iter 2400000  cost=50.3704  accept rate=0.26
#   iter 2410000  cost=50.3100  accept rate=0.26
#   iter 2420000  cost=50.7255  accept rate=0.26
#   iter 2430000  cost=50.8176  accept rate=0.26
#   iter 2440000  cost=50.9811  accept rate=0.26
#   iter 2450000  cost=52.7402  accept rate=0.26
#   iter 2460000  cost=51.6641  accept rate=0.26
#   iter 2470000  cost=51.1781  accept rate=0.26
#   iter 2480000  cost=51.9864  accept rate=0.26
#   iter 2490000  cost=51.2951  accept rate=0.26
#   iter 2500000  cost=50.7041  accept rate=0.26
#   iter 2510000  cost=50.6318  accept rate=0.26
#   iter 2520000  cost=51.7315  accept rate=0.26
#   iter 2530000  cost=51.2620  accept rate=0.26
#   iter 2540000  cost=50.8676  accept rate=0.26
#   iter 2550000  cost=51.0804  accept rate=0.26
#   iter 2560000  cost=55.7382  accept rate=0.26
#   iter 2570000  cost=51.5732  accept rate=0.26
#   iter 2580000  cost=51.0245  accept rate=0.26
#   iter 2590000  cost=52.5624  accept rate=0.26
#   iter 2600000  cost=50.4369  accept rate=0.26
#   iter 2610000  cost=51.0078  accept rate=0.26
#   iter 2620000  cost=51.4897  accept rate=0.26
#   iter 2630000  cost=50.5327  accept rate=0.26
#   iter 2640000  cost=50.9707  accept rate=0.26
#   iter 2650000  cost=51.2774  accept rate=0.26
#   iter 2660000  cost=52.8421  accept rate=0.26
#   iter 2670000  cost=50.5391  accept rate=0.26
#   iter 2680000  cost=51.8704  accept rate=0.26
#   iter 2690000  cost=51.1370  accept rate=0.26
#   iter 2700000  cost=51.1368  accept rate=0.26
#   iter 2710000  cost=50.2532  accept rate=0.26
#   iter 2720000  cost=50.7082  accept rate=0.26
#   iter 2730000  cost=50.4931  accept rate=0.26
#   iter 2740000  cost=51.3062  accept rate=0.26
#   iter 2750000  cost=51.1327  accept rate=0.26
#   iter 2760000  cost=53.4264  accept rate=0.26
#   iter 2770000  cost=50.9586  accept rate=0.26
#   iter 2780000  cost=52.0219  accept rate=0.26
#   iter 2790000  cost=50.2382  accept rate=0.26
#   iter 2800000  cost=50.5463  accept rate=0.26
#   iter 2810000  cost=51.7037  accept rate=0.26
#   iter 2820000  cost=50.3071  accept rate=0.26
#   iter 2830000  cost=50.8141  accept rate=0.26
#   iter 2840000  cost=50.2978  accept rate=0.26
#   iter 2850000  cost=51.9386  accept rate=0.26
#   iter 2860000  cost=51.4859  accept rate=0.26
#   iter 2870000  cost=52.4780  accept rate=0.26
#   iter 2880000  cost=52.1875  accept rate=0.26
#   iter 2890000  cost=50.9109  accept rate=0.26
#   iter 2900000  cost=51.2779  accept rate=0.26
#   iter 2910000  cost=51.1809  accept rate=0.26
#   iter 2920000  cost=51.0051  accept rate=0.26
#   iter 2930000  cost=51.4066  accept rate=0.26
#   iter 2940000  cost=51.4755  accept rate=0.26
#   iter 2950000  cost=51.6045  accept rate=0.26
#   iter 2960000  cost=51.5137  accept rate=0.26
#   iter 2970000  cost=51.4645  accept rate=0.26
#   iter 2980000  cost=50.2554  accept rate=0.26
#   iter 2990000  cost=51.3138  accept rate=0.26
#   iter 3000000  cost=53.1704  accept rate=0.26
#   iter 3010000  cost=50.8189  accept rate=0.26
#   iter 3020000  cost=51.1293  accept rate=0.26
#   iter 3030000  cost=50.4628  accept rate=0.26
#   iter 3040000  cost=50.5307  accept rate=0.26
#   iter 3050000  cost=50.8696  accept rate=0.26
#   iter 3060000  cost=50.9376  accept rate=0.26
#   iter 3070000  cost=51.4005  accept rate=0.26
#   iter 3080000  cost=53.5758  accept rate=0.26
#   iter 3090000  cost=52.3682  accept rate=0.26
#   iter 3100000  cost=51.8365  accept rate=0.26
#   iter 3110000  cost=50.8783  accept rate=0.26
#   iter 3120000  cost=53.4336  accept rate=0.26
#   iter 3130000  cost=52.5438  accept rate=0.26
#   iter 3140000  cost=52.7611  accept rate=0.26
#   iter 3150000  cost=50.6406  accept rate=0.26
#   iter 3160000  cost=53.3352  accept rate=0.26
#   iter 3170000  cost=52.4125  accept rate=0.26
#   iter 3180000  cost=53.7923  accept rate=0.26
#   iter 3190000  cost=53.2065  accept rate=0.26
#   iter 3200000  cost=53.0073  accept rate=0.26
#   iter 3210000  cost=54.7475  accept rate=0.26
#   iter 3220000  cost=54.3746  accept rate=0.26
#   iter 3230000  cost=53.9859  accept rate=0.26
#   iter 3240000  cost=53.5418  accept rate=0.26
#   iter 3250000  cost=56.1908  accept rate=0.26
#   iter 3260000  cost=53.0361  accept rate=0.26
#   iter 3270000  cost=51.3425  accept rate=0.26
#   iter 3280000  cost=51.2589  accept rate=0.26
#   iter 3290000  cost=52.5277  accept rate=0.26
#   iter 3300000  cost=53.6473  accept rate=0.26
#   iter 3310000  cost=52.9839  accept rate=0.26
#   iter 3320000  cost=51.4700  accept rate=0.26
#   iter 3330000  cost=50.1883  accept rate=0.26
#   iter 3340000  cost=51.6200  accept rate=0.26
#   iter 3350000  cost=50.4576  accept rate=0.26
#   iter 3360000  cost=50.3498  accept rate=0.26
#   iter 3370000  cost=51.4461  accept rate=0.26
#   iter 3380000  cost=51.7374  accept rate=0.26
#   iter 3390000  cost=51.3470  accept rate=0.26
#   iter 3400000  cost=50.3006  accept rate=0.26
#   iter 3410000  cost=51.5729  accept rate=0.26
#   iter 3420000  cost=50.2868  accept rate=0.26
#   iter 3430000  cost=52.3323  accept rate=0.26
#   iter 3440000  cost=51.7478  accept rate=0.26
#   iter 3450000  cost=50.7889  accept rate=0.26
#   iter 3460000  cost=51.6420  accept rate=0.26
#   iter 3470000  cost=52.1158  accept rate=0.26
#   iter 3480000  cost=55.5474  accept rate=0.26
#   iter 3490000  cost=51.1262  accept rate=0.26
#   iter 3500000  cost=52.0820  accept rate=0.26
#   iter 3510000  cost=51.4807  accept rate=0.26
#   iter 3520000  cost=54.0100  accept rate=0.26
#   iter 3530000  cost=51.7523  accept rate=0.26
#   iter 3540000  cost=51.1995  accept rate=0.26
#   iter 3550000  cost=58.0222  accept rate=0.26
#   iter 3560000  cost=50.9507  accept rate=0.26
#   iter 3570000  cost=50.5253  accept rate=0.26
#   iter 3580000  cost=51.3035  accept rate=0.26
#   iter 3590000  cost=50.8085  accept rate=0.26
#   iter 3600000  cost=56.2992  accept rate=0.26
#   iter 3610000  cost=51.8326  accept rate=0.26
#   iter 3620000  cost=52.9556  accept rate=0.26
#   iter 3630000  cost=51.6874  accept rate=0.26
#   iter 3640000  cost=51.0846  accept rate=0.26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 37
#      33 other_weights = other_weights/np.max(other_weights)
#      36 # --- run ---
# ---> 37 final_state, saved_path = run_mcmc(
#      38     obs_z          = obs_z,
#      39     obs_val        = obs_val,
#      40     init_p         = init_p,
#      41     param_cfg      = param_cfg,
#      42     num_iterations = 5_000_000,
#      43     output_name    = f'Idealized_param_set_chain_Da_kappa_C_GoodWeights_5mio_its.h5',
#      44     weights        = other_weights
#      45 )
#
# File c:\Users\Træning 3\OneDrive - Roskilde Universitet\12. semester\Speciale - General\Numerik\Scripts\MCMC\it4\param_estim_it4_alteration.py:185, in run_mcmc(obs_z, obs_val, init_p, param_cfg, num_iterations, output_name, weights)
#     182     candidate[name] = prop
#     184 if valid:
# --> 185     model_cand = forward(**candidate)
#     186     cost_cand  = log_space_cost(model_cand, obs_val, weights)
#     188     log_alpha = -(cost_cand - cost_curr)
#
# File c:\Users\Træning 3\OneDrive - Roskilde Universitet\12. semester\Speciale - General\Numerik\Scripts\MCMC\it4\param_estim_it4_alteration.py:134, in run_mcmc.<locals>.forward(**params)
#     131 _kappa = params.get('kappa', init_p.get('kappa'))
#     132 _C     = params.get('C',    init_p.get('C'))
# --> 134 B = B_funky(z_grid, t, _u1, _u2, _alpha, _Da, _kappa, _C, t_array)
#     135 if not np.all(np.isfinite(B)):
#     136     return np.full(len(obs_z), np.nan)
#
# File c:\Users\Træning 3\OneDrive - Roskilde Universitet\12. semester\Speciale - General\Numerik\Scripts\MCMC\it4\it4_anal_solver.py:81, in B_funky(z_phys, t, u1, u2, alpha, Da, kappa, C, t_array)
#      79 B1 = B_func51(z1, t, u1, alpha, lambda_, kappa, C)
#      80 M_vals = interface_M(t_array, u1, u2, alpha, lambda_, kappa, C)
# ---> 81 B2 = B_func52(z2, t, u2, alpha, lambda_, t_array, kappa, M_vals, C)
#      82 B = np.concatenate((B1, B2))
#      83 A = C * np.exp(-lambda_ * z_phys)
#
# File c:\Users\Træning 3\OneDrive - Roskilde Universitet\12. semester\Speciale - General\Numerik\Scripts\MCMC\it4\it4_anal_solver.py:65, in B_funky.<locals>.B_func52(z2_phys, t_val, u2, alpha, lambda_, t_array, kappa, M_vals, C)
#      62 tau = np.clip(t_val - tau_travel, 0.0, t_array[-1])
#      64 # M interpolated at the retarded time
# ---> 65 M_tau = np.interp(tau, t_array, M_vals)
#      67 # Branch 1: characteristic has arrived (z2 ≤ u2·t_val)
#      68 b1 = ( (alpha / a2) * C * np.exp(-lambda_ * z2_phys)
#      69     + (M_tau - (alpha / a2) * C * np.exp(-lambda_ * 50.0))
#      70         * np.exp(-kappa * tau_travel) )
#
# File c:\Users\Træning 3\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_function_base_impl.py:1663, in interp(x, xp, fp, left, right, period)
#    1660     xp = np.concatenate((xp[-1:]-period, xp, xp[0:1]+period))
#    1661     fp = np.concatenate((fp[-1:], fp, fp[0:1]))
# -> 1663 return interp_func(x, xp, fp, left, right)
#
# KeyboardInterrupt:

# %%
sigma_obs    = np.where(obs_val > 0, 0.5 * obs_val, 1.0)
weights_real = 1.0 / sigma_obs**2
plt.plot(weights_real, obs_z)
plt.show()

weights_real = obs_val / np.max(obs_val)
plt.plot(weights_real, obs_z)
plt.show()

other_weights = np.concatenate([
    water_val / np.max(water_val),
    sed_val   / np.max(sed_val)*0.05,
    np.zeros(len(pad_z))
])
plt.plot(other_weights, obs_z)
plt.show()

# %%
from param_estim_it4_alteration import load_chain
saved_path = "chain_Da_kappa_C=60.0_nummer2_GoodWeights_5mio_its_26_05_21_15_58.h5"
chain, costs, names, _ = load_chain(saved_path, burnin=500)

# --- Cost trace ---
fig, axes = plt.subplots(len(names) + 1, 1, figsize=(12, 3 * (len(names) + 1)), sharex=False)

axes[0].plot(costs)
axes[0].set_ylabel('cost')
axes[0].set_xlabel('iteration (post-burnin)')
axes[0].set_title('Cost trace')

# --- Parameter traces (accepted samples) ---
for i, name in enumerate(names):
    axes[i + 1].plot(chain[:, i])
    axes[i + 1].set_ylabel(name)
    axes[i + 1].set_xlabel('accepted sample')

plt.tight_layout()
plt.show()

# --- Marginal histograms ---
fig, axes = plt.subplots(1, len(names), figsize=(4 * len(names), 4))
for i, name in enumerate(names):
    axes[i].hist(chain[:, i], bins=100, density=True)
    axes[i].axvline(np.median(chain[:, i]), color='r', linestyle='--', label='median')
    axes[i].set_xlabel(name)
    axes[i].set_ylabel('density')
    axes[i].legend()

plt.tight_layout()
plt.show()

# --- Posterior summaries ---
print("Posterior summaries (95% CI):")
for i, name in enumerate(names):
    med = np.median(chain[:, i])
    lo, hi = np.percentile(chain[:, i], [2.5, 97.5])
    print(f"  {name:10s}: median={med:.4g}  95% CI=[{lo:.4g}, {hi:.4g}]")
# Out:
# c:\Users\Træning 3\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_histograms_impl.py:902: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# c:\Users\Træning 3\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Træning 3\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Posterior summaries (95% CI):
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 38
#      36 for i, name in enumerate(names):
#      37     med = np.median(chain[:, i])
# ---> 38     lo, hi = np.percentile(chain[:, i], [2.5, 97.5])
#      39     print(f"  {name:10s}: median={med:.4g}  95% CI=[{lo:.4g}, {hi:.4g}]")
#
# File c:\Users\Træning 3\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_function_base_impl.py:4238, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4235     if np.any(weights < 0):
#    4236         raise ValueError("Weights must be non-negative.")
# -> 4238 return _quantile_unchecked(
#    4239     a, q, axis, out, overwrite_input, method, keepdims, weights)
#
# File c:\Users\Træning 3\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_function_base_impl.py:4517, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4508 def _quantile_unchecked(a,
#    4509                         q,
#    4510                         axis=None,
#    (...)
#    4514                         keepdims=False,
#    4515                         weights=None):
#    4516     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4517     return _ureduce(a,
#    4518                     func=_quantile_ureduce_func,
#    4519                     q=q,
#    4520                     weights=weights,
#    4521                     keepdims=keepdims,
#    4522                     axis=axis,
#    4523                     out=out,
#    4524                     overwrite_input=overwrite_input,
#    4525                     method=method)
#
# File c:\Users\Træning 3\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_function_base_impl.py:3848, in _ureduce(a, func, keepdims, **kwargs)
#    3845             index_out = (0, ) * nd
#    3846             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3848 r = func(a, **kwargs)
#    3850 if out is not None:
#    3851     return out
#
# File c:\Users\Træning 3\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_function_base_impl.py:4694, in _quantile_ureduce_func(a, q, weights, axis, out, overwrite_input, method)
#    4692         arr = a.copy()
#    4693         wgt = weights
# -> 4694 result = _quantile(arr,
#    4695                    quantiles=q,
#    4696                    axis=axis,
#    4697                    method=method,
#    4698                    out=out,
#    4699                    weights=wgt)
#    4700 return result
#
# File c:\Users\Træning 3\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_function_base_impl.py:4816, in _quantile(arr, quantiles, axis, method, out, weights)
#    4809 arr.partition(
#    4810     np.unique(np.concatenate(([0, -1],
#    4811                               previous_indexes.ravel(),
#    4812                               next_indexes.ravel(),
#    4813                               ))),
#    4814     axis=0)
#    4815 if supports_nans:
# -> 4816     slices_having_nans = np.isnan(arr[-1, ...])
#    4817 else:
#    4818     slices_having_nans = None
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
#combichains = np.concatenate([chain1, chain])
#combicosts = np.concatenate([costs1, costs])

combichains = chain

# %%
#combichains = np.concatenate([chain1, chain])
#combicosts = np.concatenate([costs1, costs])

# %%
combichains = chain

# --- Estimated solution vs observations ---
alpha_est  = alpha#np.median(chain[:, names.index('alpha')])
Da_est     = np.median(combichains[:, names.index('Da')])
C_est     = np.median(combichains[:, names.index('C')])
kappa_est  = np.median(combichains[:, names.index('kappa')])
u1_est     = u1#np.median(chain[:, names.index('u1')])
u2_est     = u2#np.median(chain[:, names.index('u2')])
print(Da_est, C_est, kappa_est)

z_plot  = np.linspace(0, 150, 1500)
t_final = 70.0
t_plot  = np.linspace(0, t_final, 1000)
total_est   = B_funky(z_plot, t_final, u1_est, u2_est, alpha_est, Da_est, kappa_est, C_est, t_plot)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 8), sharey=True)

title_str = (
    f'Da={Da_est},  κ={kappa_est},  C={C_est},'
    f'u1={u1_est},  u2={u2_est},  α={alpha_est}'
)

# --- Left: log x ---
ax1.plot(total_est, z_plot, label='A + B (estimated)', color='tab:blue')
ax1.scatter(obs_val, obs_z, color='k', label='observations', s=3)
ax1.axhline(y=50, linestyle='--', color='gray', label='seabed')
ax1.set_xlabel('Concentration (log scale)')
ax1.set_ylabel('Depth (m)')
ax1.set_title('Log x-axis')
ax1.set_xscale('log')

ax1.grid()
ax1.legend()

# --- Right: linear x ---
ax2.plot(total_est, z_plot, label='A + B (estimated)', color='tab:blue')
ax2.scatter(obs_val, obs_z, color='k', label='observations', s=3)
ax2.axhline(y=50, linestyle='--', color='gray', label='seabed')
ax2.set_xlabel('Concentration (linear scale)')
ax2.set_title('Linear x-axis')
ax2.grid()
ax2.legend()
#ax2.set_xlim(-1, 500)

ax1.invert_yaxis()
#ax2.set_ylim(0, 70)

#ax2.invert_yaxis()
fig.suptitle(f'Estimated solution\n{title_str}', y=1.01)
plt.tight_layout()
plt.show()


A = C_est*np.exp(-(alpha_est/Da_est) * z_plot)
plt.plot(A, z_plot, 'k-.', label = "A (source)")
plt.legend()
plt.gca().invert_yaxis()
plt.xlabel("Concentration")
plt.ylabel("Depth (m)")
plt.grid()
plt.tight_layout()
plt.show()

print(C_est*np.exp(-(alpha_est/Da_est) * 50))
# Out:
# 9.927121208786362 62.37074502196575 0.1067250254150932
# 0.08791264114323455

# %%
plt.scatter(obs_val, obs_z, color='k', label='observations')#, s=3)
plt.ylim(45, 55)
# Out:
# (45.0, 55.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- Confidence interval calculation ---
def get_ci_bounds(chain, names, chain1, names1, z_plot, t_final, t_plot,
                  alpha, u1, u2, n_samples=500, ci=95):
    """
    Sample parameters from the chain and compute CI bounds on the solution.
    """
    lower_p = (100 - ci) / 2
    upper_p = 100 - lower_p

    # Pool both chains for each estimated parameter
    Da_samples    = np.concatenate([chain[:, names.index('Da')],
                                    chain1[:, names1.index('Da')]])
    kappa_samples = np.concatenate([chain[:, names.index('kappa')],
                                    chain1[:, names1.index('kappa')]])
    C_samples     = np.concatenate([chain[:, names.index('C')],
                                    chain1[:, names1.index('C')]])

    # Draw random samples
    idx = np.random.choice(len(Da_samples), size=n_samples, replace=False)
    solutions = []
    for i in idx:
        sol = B_funky(z_plot, t_final, u1, u2, alpha,
                      Da_samples[i], kappa_samples[i], C_samples[i], t_plot)
        solutions.append(sol)

    solutions = np.array(solutions)
    lower = np.percentile(solutions, lower_p, axis=0)
    upper = np.percentile(solutions, upper_p, axis=0)
    return lower, upper


# --- Estimated solution ---
alpha_est = alpha
Da_est    = np.mean(combichains[:, names.index('Da')])
C_est     = np.mean(combichains[:, names.index('C')])
kappa_est = np.mean(combichains[:, names.index('kappa')])
u1_est    = u1
u2_est    = u2

print(Da_est, C_est, kappa_est)

z_plot  = np.linspace(0, 150, 1500)
t_final = 70.0
t_plot  = np.linspace(0, t_final, 1000)

total_est = B_funky(z_plot, t_final, u1_est, u2_est, alpha_est,
                    Da_est, kappa_est, C_est, t_plot)

# Compute CI bounds
ci_lower, ci_upper = get_ci_bounds(chain, names, chain1, names1,
                                   z_plot, t_final, t_plot,
                                   alpha_est, u1_est, u2_est)

title_str = (
    f'α={alpha_est:.4f},  Da={Da_est:.4f},  κ={kappa_est:.4f},  '
    f'u1={u1_est:.4f},  u2={u2_est:.4f},  C={C_est:.4f}'
)


def make_panel(ax, xscale='linear', ylim=None, xlabel='Concentration'):
    """Helper to plot solution, CI band and observations on a given axis."""
    # CI shading
    ax.fill_betweenx(z_plot, ci_lower, ci_upper,
                     alpha=0.3, color='gray', label='95% CI')
    # Mean solution
    ax.plot(total_est, z_plot,
            label='A + B (estimated)', color='tab:blue')
    # CI edges
    ax.plot(ci_lower, z_plot,
            color='gray', linewidth=0.8, linestyle='--')
    ax.plot(ci_upper, z_plot,
            color='gray', linewidth=0.8, linestyle='--')
    # Observations
    ax.scatter(obs_val, obs_z,
               color='k', label='Observations', s=3, zorder=5)
    # Seabed
    ax.axhline(y=50, linestyle='--', color='gray', label='Seabed')
    ax.set_xlabel(xlabel)
    ax.set_xscale(xscale)
    if ylim is not None:
        ax.set_ylim(ylim)
    ax.invert_yaxis()
    ax.grid()
    ax.legend(fontsize=8)


# ---------------------------------------------------------------
# Figure 1: Full domain 0-150, log and linear
# ---------------------------------------------------------------
fig1, axes1 = plt.subplots(1, 2, figsize=(14, 8), sharey=True)

make_panel(axes1[0], xscale='log',
           xlabel='Concentration (log scale)')
axes1[0].set_ylabel('Depth (m)')
axes1[0].set_title('Log x-axis')

make_panel(axes1[1], xscale='linear',
           xlabel='Concentration (linear scale)')
axes1[1].set_title('Linear x-axis')

fig1.suptitle(f'Estimated solution — full domain (0–150 m)\n{title_str}',
              y=1.01)
plt.tight_layout()
plt.gca().invert_yaxis()
plt.show()


# ---------------------------------------------------------------
# Figure 2: Zoomed 0-60 m, log and linear
# ---------------------------------------------------------------
fig2, axes2 = plt.subplots(1, 2, figsize=(14, 8), sharey=True)

make_panel(axes2[0], xscale='log',
           ylim=(0, 60),
           xlabel='Concentration (log scale)')
axes2[0].set_ylabel('Depth (m)')
axes2[0].set_title('Log x-axis')

make_panel(axes2[1], xscale='linear',
           ylim=(0, 60),
           xlabel='Concentration (linear scale)')
axes2[1].set_title('Linear x-axis')

fig2.suptitle(f'Estimated solution — zoomed (0–60 m)\n{title_str}',
              y=1.01)
plt.tight_layout()
plt.show()


# ---------------------------------------------------------------
# Figure 3: Zoomed 40-60 m, log and linear
# ---------------------------------------------------------------
fig3, axes3 = plt.subplots(1, 2, figsize=(14, 8), sharey=True)

make_panel(axes3[0], xscale='log',
           ylim=(48, 55),
           xlabel='Concentration (log scale)')
axes3[0].set_ylabel('Depth (m)')
axes3[0].set_title('Log x-axis')

make_panel(axes3[1], xscale='linear',
           ylim=(48, 55),
           xlabel='Concentration (linear scale)')
axes3[1].set_title('Linear x-axis')

fig3.suptitle(f'Estimated solution — zoomed (40–60 m)\n{title_str}',
              y=1.01)
plt.tight_layout()
plt.show()


# ---------------------------------------------------------------
# Source term A
# ---------------------------------------------------------------
A = C_est * np.exp(-(alpha_est / Da_est) * z_plot)
plt.figure(figsize=(6, 8))
plt.plot(A, z_plot, 'k-.', label='A (source)')
plt.gca().invert_yaxis()
plt.xlabel('Concentration')
plt.ylabel('Depth (m)')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

print(C_est * np.exp(-(alpha_est / Da_est) * 50))
# Out:
# 9.25839412640072 127.4795190341697 0.09077839111812291
# c:\Users\Træning 3\OneDrive - Roskilde Universitet\12. semester\Speciale - General\Numerik\Scripts\MCMC\it4\it4_anal_solver.py:16: RuntimeWarning: overflow encountered in exp
#   b_tr  = (alpha / a) * np.exp(-lambda_ * z) * (1 - np.exp(-a * t_val))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 53
#      49 total_est = B_funky(z_plot, t_final, u1_est, u2_est, alpha_est,
#      50                     Da_est, kappa_est, C_est, t_plot)
#      52 # Compute CI bounds
# ---> 53 ci_lower, ci_upper = get_ci_bounds(chain, names, chain1, names1,
#      54                                    z_plot, t_final, t_plot,
#      55                                    alpha_est, u1_est, u2_est)
#      57 title_str = (
#      58     f'α={alpha_est:.4f},  Da={Da_est:.4f},  κ={kappa_est:.4f},  '
#      59     f'u1={u1_est:.4f},  u2={u2_est:.4f},  C={C_est:.4f}'
#      60 )
#      63 def make_panel(ax, xscale='linear', ylim=None, xlabel='Concentration'):
#
# NameError: name 'chain1' is not defined
