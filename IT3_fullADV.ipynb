# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad

# %%
z = np.linspace(0, 140, 200)
t =np.linspace(0, 1.6, 200)  # in years

# Parameters (you can change these)
alpha = 1.74
Da=1
kappa = 1.42*10**(-2)
lambda_ = np.sqrt(alpha/Da)

# %%
u = 10**(-2)+(3.66*10**4)/(1+np.exp(z-50))
plt.figure(figsize=(10, 6))
plt.plot( u,z, label='Velocity Profile u(z)')   
plt.ylabel('Depth (z)')
plt.xlabel('Velocity (u)')
#plt.title('Velocity Profile u(z) vs Depth z')
plt.gca().invert_yaxis()  # Invert y-axis to show depth increasing downwards
plt.grid()
plt.legend()
plt.show()
